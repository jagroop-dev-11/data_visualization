# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
sales_data = pd.read_csv('data.csv')
sales_data.head(5)
# Out:
#          Date Category  Value   Product  Sales Region
# 0  2023-01-01        A   28.0  Product1  754.0   East
# 1  2023-01-02        B   39.0  Product3  110.0  North
# 2  2023-01-03        C   32.0  Product2  398.0   East
# 3  2023-01-04        B    8.0  Product1  522.0   East
# 4  2023-01-05        B   26.0  Product3  869.0  North

# %%
sales_data.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       3
# Product     0
# Sales       4
# Region      0
# dtype: int64

# %%
sales_data["Sales"] = sales_data["Sales"].fillna(sales_data["Sales"].mean())
sales_data["Value"] = sales_data["Value"].fillna(sales_data["Value"].mean())

# %%
sales_data.isnull().sum()
# Out:
# Date        0
# Category    0
# Value       0
# Product     0
# Sales       0
# Region      0
# dtype: int64

# %%
sales_by_region = sales_data.groupby("Region")["Sales"].sum()
sales_by_region
# Out:
# Region
# East     7574.130435
# North    6565.130435
# South    5158.000000
# West     8559.260870
# Name: Sales, dtype: float64

# %%
sales_by_region.plot(kind="bar",color="pink")
plt.xlabel("Region")
plt.ylabel("Sales")
plt.title("Bar chart for Sales by Region")
plt.show()

# %%
sales_by_time = sales_data.groupby("Date")["Sales"].sum().reset_index()
sales_by_time
# Out:
#           Date       Sales
# 0   2023-01-01  754.000000
# 1   2023-01-02  110.000000
# 2   2023-01-03  398.000000
# 3   2023-01-04  522.000000
# 4   2023-01-05  869.000000
# 5   2023-01-06  192.000000
# 6   2023-01-07  936.000000
# 7   2023-01-08  488.000000
# 8   2023-01-09  772.000000
# 9   2023-01-10  834.000000
# 10  2023-01-11  842.000000
# 11  2023-01-12  557.130435
# 12  2023-01-13  628.000000
# 13  2023-01-14  423.000000
# 14  2023-01-15  893.000000
# 15  2023-01-16  895.000000
# 16  2023-01-17  511.000000
# 17  2023-01-18  108.000000
# 18  2023-01-19  578.000000
# 19  2023-01-20  736.000000
# 20  2023-01-21  606.000000
# 21  2023-01-22  992.000000
# 22  2023-01-23  942.000000
# 23  2023-01-24  342.000000
# 24  2023-01-25  458.000000
# 25  2023-01-26  584.000000
# 26  2023-01-27  619.000000
# 27  2023-01-28  224.000000
# 28  2023-01-29  617.000000
# 29  2023-01-30  737.000000
# 30  2023-01-31  735.000000
# 31  2023-02-01  189.000000
# 32  2023-02-02  338.000000
# ...

# %%
plt.figure(figsize=(10,5))
plt.plot(sales_by_time["Date"],sales_by_time["Sales"],color="red")
plt.xlabel("Date")
plt.ylabel("Sales")
plt.title("Bar chart for Sales by Date")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
